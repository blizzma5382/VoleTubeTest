# %%
import pandas as pd

# %%
VTT=pd.read_csv(C:/Users/matth/Documents/retreat_counts_for_matt)
# Out:
#   Cell In[2], line 1
#     VTT=pd.read_csv(C:/Users/matth/Documents/retreat_counts_for_matt)
#                      ^
# SyntaxError: invalid syntax

# %%
VTT=pd.read_csv('C:/Users/matth/Documents/retreat_counts_for_matt.csv')

# %%
spreadsheet.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 spreadsheet.head()
#
# NameError: name 'spreadsheet' is not defined

# %%
VTT.head()
# Out:
#    Unnamed: 0  Index        date  female_ID  male_ID  female_retreat_count  \
# 0           0      0  2022-11-09       4840     4829                     2
# 1           0      1  2022-11-10       4827     4834                     0
# 2           0      2  2022-12-21       4815     4784                     0
# 3           0      3  2022-11-08       4831     4824                     4
# 4           0      4  2022-12-07       4825     4830                     1
#
#    male_retreat_count  conflict_count
# 0                   1               4
# 1                   2               2
# 2                   0               0
# 3                   0               3
# 4                   1               2

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTT.mean('female_retreat_count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'female_retreat_count'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 VTT.mean('female_retreat_count')
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# ...

# %%
VTT.mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_9164\1852924708.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   VTT.mean()
# Unnamed: 0                 0.000000
# Index                     10.500000
# female_ID               4825.545455
# male_ID                 4817.000000
# female_retreat_count       0.772727
# male_retreat_count         1.454545
# conflict_count             1.681818
# dtype: float64

# %%
VTT.groupby('female_ID').mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_9164\894442108.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   VTT.groupby('female_ID').mean()
#            Unnamed: 0      Index  male_ID  female_retreat_count  \
# female_ID
# 4814              0.0  17.500000   4781.0              0.000000
# 4815              0.0  11.000000   4784.0              0.000000
# 4818              0.0  14.000000   4787.0              1.000000
# 4819              0.0  13.000000   4833.0              1.000000
# 4825              0.0   8.333333   4830.0              0.666667
# 4827              0.0   9.000000   4834.0              0.000000
# 4828              0.0   6.500000   4835.0              0.000000
# 4831              0.0   7.666667   4824.0              1.333333
# ...

# %%
VTT.groupby('male_ID').mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_9164\427308591.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   VTT.groupby('male_ID').mean()
#          Unnamed: 0      Index  female_ID  female_retreat_count  \
# male_ID
# 4781            0.0  17.500000     4814.0              0.000000
# 4784            0.0  11.000000     4815.0              0.000000
# 4787            0.0  14.000000     4818.0              1.000000
# 4823            0.0  15.500000     4836.0              1.000000
# 4824            0.0   7.666667     4831.0              1.333333
# 4829            0.0   5.000000     4840.0              2.500000
# 4830            0.0   8.333333     4825.0              0.666667
# 4833            0.0  13.000000     4819.0              1.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
VTT.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 VTT.bar()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %%
VTT.plot(x=['female_retreat_count', 'male_retreat_count'], kind=bar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 VTT.plot(x=['female_retreat_count', 'male_retreat_count'], kind=bar)
#
# NameError: name 'bar' is not defined

# %%
VTT.plot(x=['female_retreat_count', 'male_retreat_count'], kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 VTT.plot(x=['female_retreat_count', 'male_retreat_count'], kind="bar")
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:966, in PlotAccessor.__call__(self, *args, **kwargs)
#     964         x = data_cols[x]
#     965     elif not isinstance(data[x], ABCSeries):
# --> 966         raise ValueError("x must be a label or position")
#     967     data = data.set_index(x)
#     968 if y is not None:
#     969     # check if we have y as int or list of ints
#
# ValueError: x must be a label or position

# %%
VTT.plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTT.plot()
# Out:
# <AxesSubplot: >

# %%
VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:966, in PlotAccessor.__call__(self, *args, **kwargs)
#     964         x = data_cols[x]
#     965     elif not isinstance(data[x], ABCSeries):
# --> 966         raise ValueError("x must be a label or position")
#     967     data = data.set_index(x)
#     968 if y is not None:
#     969     # check if we have y as int or list of ints
#
# ValueError: x must be a label or position

# %%
VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'], kind=bar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'], kind=bar)
#
# NameError: name 'bar' is not defined

# %%
VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'], kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 VTT.plot(x=['female_ID', 'male_ID'], y=['female_retreat_count', 'male_retreat_count'], kind="bar")
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:966, in PlotAccessor.__call__(self, *args, **kwargs)
#     964         x = data_cols[x]
#     965     elif not isinstance(data[x], ABCSeries):
# --> 966         raise ValueError("x must be a label or position")
#     967     data = data.set_index(x)
#     968 if y is not None:
#     969     # check if we have y as int or list of ints
#
# ValueError: x must be a label or position

# %%
VTT.plot(x='female_ID', y='female_retreat_count')
# Out:
# <AxesSubplot: xlabel='female_ID'>

# %%
VTT.plot(x='female_ID', y='female_retreat_count', kind="bar")
# Out:
# <AxesSubplot: xlabel='female_ID'>

# %%
groupby('female_ID').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 groupby('female_ID').mean()
#
# NameError: name 'groupby' is not defined

# %%
.groupby('female_ID').mean()
# Out:
#   Cell In[24], line 1
#     .groupby('female_ID').mean()
#     ^
# SyntaxError: invalid syntax

# %%
VTT.groupby('female_ID').mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_9164\894442108.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   VTT.groupby('female_ID').mean()
#            Unnamed: 0      Index  male_ID  female_retreat_count  \
# female_ID
# 4814              0.0  17.500000   4781.0              0.000000
# 4815              0.0  11.000000   4784.0              0.000000
# 4818              0.0  14.000000   4787.0              1.000000
# 4819              0.0  13.000000   4833.0              1.000000
# 4825              0.0   8.333333   4830.0              0.666667
# 4827              0.0   9.000000   4834.0              0.000000
# 4828              0.0   6.500000   4835.0              0.000000
# 4831              0.0   7.666667   4824.0              1.333333
# ...

# %%
VTT.groupby('female_ID').mean('female_retreat_count')
# Out:
#            Unnamed: 0      Index  male_ID  female_retreat_count  \
# female_ID
# 4814              0.0  17.500000   4781.0              0.000000
# 4815              0.0  11.000000   4784.0              0.000000
# 4818              0.0  14.000000   4787.0              1.000000
# 4819              0.0  13.000000   4833.0              1.000000
# 4825              0.0   8.333333   4830.0              0.666667
# 4827              0.0   9.000000   4834.0              0.000000
# 4828              0.0   6.500000   4835.0              0.000000
# 4831              0.0   7.666667   4824.0              1.333333
# 4836              0.0  15.500000   4823.0              1.000000
# 4840              0.0   5.000000   4829.0              2.500000
#
#            male_retreat_count  conflict_count
# female_ID
# 4814                 1.500000             1.0
# 4815                 0.500000             0.5
# 4818                 1.000000             2.0
# 4819                 5.500000             1.5
# ...

# %%
VTT['female_retreat_count'].groupby('female_ID').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 VTT['female_retreat_count'].groupby('female_ID').mean()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\series.py:2076, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2073     raise TypeError("You have to supply one of 'by' and 'level'")
#    2074 axis = self._get_axis_number(axis)
# -> 2076 return SeriesGroupBy(
#    2077     obj=self,
#    2078     keys=by,
#    2079     axis=axis,
#    2080     level=level,
#    2081     as_index=as_index,
#    2082     sort=sort,
#    2083     group_keys=group_keys,
#    2084     squeeze=squeeze,
#    2085     observed=observed,
#    2086     dropna=dropna,
#    2087 )
#
# ...

# %%
VTT.mean('female_retreat_count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'female_retreat_count'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 VTT.mean('female_retreat_count')
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# ...

# %%
VTT.mean("female_retreat_count")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'female_retreat_count'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 VTT.mean("female_retreat_count")
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# ...

# %%
VTT.mean(axis=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 VTT.mean(axis=3)
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# ...

# %%
display(VTT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 display(VTT)
#
# NameError: name 'VTT' is not defined

# %%
display(VTT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 display(VTT)
#
# NameError: name 'VTT' is not defined

# %%
VTT=pd.read_csv('C:/Users/matth/Documents/retreat_counts_for_matt.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 VTT=pd.read_csv('C:/Users/matth/Documents/retreat_counts_for_matt.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
VTT=pd.read_csv('C:/Users/matth/Documents/retreat_counts_for_matt.csv')

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTT.mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_7772\1852924708.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   VTT.mean()
# Unnamed: 0                 0.000000
# Index                     10.500000
# female_ID               4825.545455
# male_ID                 4817.000000
# female_retreat_count       0.772727
# male_retreat_count         1.454545
# conflict_count             1.681818
# dtype: float64

# %%
VTT.groupby('female_ID').mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_7772\894442108.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   VTT.groupby('female_ID').mean()
#            Unnamed: 0      Index  male_ID  female_retreat_count  \
# female_ID
# 4814              0.0  17.500000   4781.0              0.000000
# 4815              0.0  11.000000   4784.0              0.000000
# 4818              0.0  14.000000   4787.0              1.000000
# 4819              0.0  13.000000   4833.0              1.000000
# 4825              0.0   8.333333   4830.0              0.666667
# 4827              0.0   9.000000   4834.0              0.000000
# 4828              0.0   6.500000   4835.0              0.000000
# 4831              0.0   7.666667   4824.0              1.333333
# ...

# %%
import matplotlib.pyplot as plt

# %%
VTT.plot.bar(x=2)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
VTT.plot.bar(x=3)
# Out:
# <AxesSubplot: xlabel='female_ID'>

# %%
VTT.plot.bar(x=3, 4)
# Out:
#   Cell In[12], line 1
#     VTT.plot.bar(x=3, 4)
#                        ^
# SyntaxError: positional argument follows keyword argument

# %%
VTT.plot.bar(x=[3, 4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 VTT.plot.bar(x=[3, 4])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:1159, in PlotAccessor.bar(self, x, y, **kwargs)
#    1071 @Appender(
#    1072     """
#    1073     See Also
#    (...)
#    1148 @Appender(_bar_or_line_doc)
#    1149 def bar(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1150     """
#    1151     Vertical bar plot.
#    1152
#    (...)
#    1157     other axis represents a measured value.
#    1158     """
# -> 1159     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
#     963 if is_integer(x) and not data.columns.holds_integer():
#     964     x = data_cols[x]
# ...

# %%
VTT.plot.bar(x-3, y=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 VTT.plot.bar(x-3, y=5)
#
# NameError: name 'x' is not defined

# %%
VTT.plot.bar(x=3, y=5)
# Out:
# <AxesSubplot: xlabel='female_ID'>

# %%
VTT.mean(female_retreat_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 VTT.mean(female_retreat_count)
#
# NameError: name 'female_retreat_count' is not defined

# %%
VTT.mean('female_retreat_count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'female_retreat_count'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 VTT.mean('female_retreat_count')
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# ...

# %%
VTT["female_retreat_count"].mean()
# Out:
# 0.7727272727272727

# %%
frcmean=VTT["female_retreat_count"].mean()

# %%
VTT.plot.bar(x=frcmean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0.7727272727272727
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
VTT.plot.bar(y=frcmean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0.7727272727272727
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
VTT['female_retreat_count','male_retreat_count'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('female_retreat_count', 'male_retreat_count')
#
# ...

# %%
VTT["female_retreat_count", "male_retreat_count"].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('female_retreat_count', 'male_retreat_count')
#
# ...

# %%
VTT[['female_retreat_count','male_retreat_count']].plot()
# Out:
# <AxesSubplot: >

# %%
VTT[['female_retreat_count','male_retreat_count']].plot.bar()
# Out:
# <AxesSubplot: >

# %%
VTT.groupby('female_ID').plot.bar()
# Out:
# female_ID
# 4814    AxesSubplot(0.125,0.11;0.775x0.77)
# 4815    AxesSubplot(0.125,0.11;0.775x0.77)
# 4818    AxesSubplot(0.125,0.11;0.775x0.77)
# 4819    AxesSubplot(0.125,0.11;0.775x0.77)
# 4825    AxesSubplot(0.125,0.11;0.775x0.77)
# 4827    AxesSubplot(0.125,0.11;0.775x0.77)
# 4828    AxesSubplot(0.125,0.11;0.775x0.77)
# 4831    AxesSubplot(0.125,0.11;0.775x0.77)
# 4836    AxesSubplot(0.125,0.11;0.775x0.77)
# 4840    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])
# Out:
# female_ID
# 4814    AxesSubplot(0.125,0.11;0.775x0.77)
# 4815    AxesSubplot(0.125,0.11;0.775x0.77)
# 4818    AxesSubplot(0.125,0.11;0.775x0.77)
# 4819    AxesSubplot(0.125,0.11;0.775x0.77)
# 4825    AxesSubplot(0.125,0.11;0.775x0.77)
# 4827    AxesSubplot(0.125,0.11;0.775x0.77)
# 4828    AxesSubplot(0.125,0.11;0.775x0.77)
# 4831    AxesSubplot(0.125,0.11;0.775x0.77)
# 4836    AxesSubplot(0.125,0.11;0.775x0.77)
# 4840    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
VTT.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 VTT.mean()
#
# NameError: name 'VTT' is not defined

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
VTT=pd.read_csv('C:/Users/matth/Documents/retreat_counts_for_matt.csv')

# %%
VTT.mean()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_15064\1852924708.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   VTT.mean()
# Unnamed: 0                 0.000000
# Index                     10.500000
# female_ID               4825.545455
# male_ID                 4817.000000
# female_retreat_count       0.772727
# male_retreat_count         1.454545
# conflict_count             1.681818
# dtype: float64

# %%
VTT[['female_retreat_count','male_retreat_count']].plot.bar()
# Out:
# <AxesSubplot: >

# %%
VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])
# Out:
# female_ID
# 4814    AxesSubplot(0.125,0.11;0.775x0.77)
# 4815    AxesSubplot(0.125,0.11;0.775x0.77)
# 4818    AxesSubplot(0.125,0.11;0.775x0.77)
# 4819    AxesSubplot(0.125,0.11;0.775x0.77)
# 4825    AxesSubplot(0.125,0.11;0.775x0.77)
# 4827    AxesSubplot(0.125,0.11;0.775x0.77)
# 4828    AxesSubplot(0.125,0.11;0.775x0.77)
# 4831    AxesSubplot(0.125,0.11;0.775x0.77)
# 4836    AxesSubplot(0.125,0.11;0.775x0.77)
# 4840    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTT[['female_retreat_count','male_retreat_count','conflict_count']].plot.bar()
# Out:
# <AxesSubplot: >

# %%
VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count', 'conflict_count'])
# Out:
# female_ID
# 4814    AxesSubplot(0.125,0.11;0.775x0.77)
# 4815    AxesSubplot(0.125,0.11;0.775x0.77)
# 4818    AxesSubplot(0.125,0.11;0.775x0.77)
# 4819    AxesSubplot(0.125,0.11;0.775x0.77)
# 4825    AxesSubplot(0.125,0.11;0.775x0.77)
# 4827    AxesSubplot(0.125,0.11;0.775x0.77)
# 4828    AxesSubplot(0.125,0.11;0.775x0.77)
# 4831    AxesSubplot(0.125,0.11;0.775x0.77)
# 4836    AxesSubplot(0.125,0.11;0.775x0.77)
# 4840    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 5)
VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])
# Out:
# female_ID
# 4814    AxesSubplot(0.125,0.11;0.775x0.77)
# 4815    AxesSubplot(0.125,0.11;0.775x0.77)
# 4818    AxesSubplot(0.125,0.11;0.775x0.77)
# 4819    AxesSubplot(0.125,0.11;0.775x0.77)
# 4825    AxesSubplot(0.125,0.11;0.775x0.77)
# 4827    AxesSubplot(0.125,0.11;0.775x0.77)
# 4828    AxesSubplot(0.125,0.11;0.775x0.77)
# 4831    AxesSubplot(0.125,0.11;0.775x0.77)
# 4836    AxesSubplot(0.125,0.11;0.775x0.77)
# 4840    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
plt.subplots(VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.subplots(VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count']))
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\matplotlib\pyplot.py:1451, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1307 """
#    1308 Create a figure and a set of subplots.
#    1309
#    (...)
#    1448
#    1449 """
#    1450 fig = figure(**fig_kw)
# -> 1451 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1452                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1453                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1454                    width_ratios=width_ratios)
#    1455 return fig, axs
#
# ...

# %%
fig, axs=plt.subplots(5, 2)
axs[0,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[0,1].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[1,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[1,1].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[2,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[2,1].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[3,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[3,1].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[4,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[4,1].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[5,0].bar(y=['female_retreat_count', 'male_retreat_count'])
axs[5,1].bar(y=['female_retreat_count', 'male_retreat_count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 fig, axs=plt.subplots(5, 2)
# ----> 2 axs[0,0].bar(y=['female_retreat_count', 'male_retreat_count'])
#       3 axs[0,1].bar(y=['female_retreat_count', 'male_retreat_count'])
#       4 axs[1,0].bar(y=['female_retreat_count', 'male_retreat_count'])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\matplotlib\__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# ...

# %%
fig, axs=plt.subplots(5, 2)
axs[0,0].bar(x='female_ID', y=['female_retreat_count', 'male_retreat_count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 fig, axs=plt.subplots(5, 2)
# ----> 2 axs[0,0].bar(x='female_ID', y=['female_retreat_count', 'male_retreat_count'])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\matplotlib\__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.bar() missing 1 required positional argument: 'height'

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 5)
axs=VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 5)
axs[0,0]=VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])

# %%
VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])
axs[0,0]=VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count'])

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 5)
for plt.subl=plots(VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count']))
# Out:
#   Cell In[20], line 2
#     for plt.subl=plots(VTT.groupby('female_ID').plot.bar(y=['female_retreat_count', 'male_retreat_count']))
#                 ^
# SyntaxError: invalid syntax

# %%
for female_ID in VTT:
    VTT.bar(y=['female_retreat_count','male_retreat_count'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 for female_ID in VTT:
# ----> 2     VTT.bar(y=['female_retreat_count','male_retreat_count'])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %%
VTT.bar(y='female_retreat_count', 'male_retreat_count')
# Out:
#   Cell In[23], line 1
#     VTT.bar(y='female_retreat_count', 'male_retreat_count')
#                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
VTT.boxplot()
# Out:
# <AxesSubplot: >

# %%
VTT.boxplot(y=['female_retreat_count', 'male_retreat_count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 VTT.boxplot(y=['female_retreat_count', 'male_retreat_count'])
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\plotting\_core.py:516, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     499 @Substitution(backend=_backend_doc)
#     500 @Appender(_boxplot_doc)
#     501 def boxplot_frame(
#    (...)
#     513     **kwargs,
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#     519         by=by,
#     520         ax=ax,
#     521         fontsize=fontsize,
#     522         rot=rot,
#     523         grid=grid,
#     524         figsize=figsize,
#     525         layout=layout,
# ...

# %%
VTT.groupby('female_ID').boxplot()
# Out:
# 4814         AxesSubplot(0.1,0.736957;0.235294x0.163043)
# 4815    AxesSubplot(0.382353,0.736957;0.235294x0.163043)
# 4818    AxesSubplot(0.664706,0.736957;0.235294x0.163043)
# 4819         AxesSubplot(0.1,0.541304;0.235294x0.163043)
# 4825    AxesSubplot(0.382353,0.541304;0.235294x0.163043)
# 4827    AxesSubplot(0.664706,0.541304;0.235294x0.163043)
# 4828         AxesSubplot(0.1,0.345652;0.235294x0.163043)
# 4831    AxesSubplot(0.382353,0.345652;0.235294x0.163043)
# 4836    AxesSubplot(0.664706,0.345652;0.235294x0.163043)
# 4840             AxesSubplot(0.1,0.15;0.235294x0.163043)
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
VTT.groupby('female_ID').boxplot()
# Out:
# 4814         AxesSubplot(0.1,0.736957;0.235294x0.163043)
# 4815    AxesSubplot(0.382353,0.736957;0.235294x0.163043)
# 4818    AxesSubplot(0.664706,0.736957;0.235294x0.163043)
# 4819         AxesSubplot(0.1,0.541304;0.235294x0.163043)
# 4825    AxesSubplot(0.382353,0.541304;0.235294x0.163043)
# 4827    AxesSubplot(0.664706,0.541304;0.235294x0.163043)
# 4828         AxesSubplot(0.1,0.345652;0.235294x0.163043)
# 4831    AxesSubplot(0.382353,0.345652;0.235294x0.163043)
# 4836    AxesSubplot(0.664706,0.345652;0.235294x0.163043)
# 4840             AxesSubplot(0.1,0.15;0.235294x0.163043)
# dtype: object

# %%
VTT.boxplot()
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt

# %%
VTT.boxplot()
# Out:
# <AxesSubplot: >

# %%
VTT=pd.read_csv(C:/Users/matth/Documents/retreat_counts_for_matt)
# Out:
#   Cell In[3], line 1
#     VTT=pd.read_csv(C:/Users/matth/Documents/retreat_counts_for_matt)
#                      ^
# SyntaxError: invalid syntax

# %%
VTT.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 VTT.plot()
#
# NameError: name 'VTT' is not defined

# %%
VTT.boxplot()
# Out:
# <AxesSubplot: >

# %%
VTT.groupby('female_ID').boxplot()
# Out:
# 4814         AxesSubplot(0.1,0.736957;0.235294x0.163043)
# 4815    AxesSubplot(0.382353,0.736957;0.235294x0.163043)
# 4818    AxesSubplot(0.664706,0.736957;0.235294x0.163043)
# 4819         AxesSubplot(0.1,0.541304;0.235294x0.163043)
# 4825    AxesSubplot(0.382353,0.541304;0.235294x0.163043)
# 4827    AxesSubplot(0.664706,0.541304;0.235294x0.163043)
# 4828         AxesSubplot(0.1,0.345652;0.235294x0.163043)
# 4831    AxesSubplot(0.382353,0.345652;0.235294x0.163043)
# 4836    AxesSubplot(0.664706,0.345652;0.235294x0.163043)
# 4840             AxesSubplot(0.1,0.15;0.235294x0.163043)
# dtype: object

# %%
VTT.groupby('female_retreat_count').boxplot()
# Out:
# 0         AxesSubplot(0.1,0.679412;0.363636x0.220588)
# 1    AxesSubplot(0.536364,0.679412;0.363636x0.220588)
# 2         AxesSubplot(0.1,0.414706;0.363636x0.220588)
# 3    AxesSubplot(0.536364,0.414706;0.363636x0.220588)
# 4             AxesSubplot(0.1,0.15;0.363636x0.220588)
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import seaborn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
VTT.stripplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 VTT.stripplot()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'stripplot'

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.stripplot(VTT)
# Out:
# <AxesSubplot: >

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
Mprop=("male_retreat_count"/["male_retreat_count"+ "female_retreat_count"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Mprop=("male_retreat_count"/["male_retreat_count"+ "female_retreat_count"])
#
# TypeError: unsupported operand type(s) for /: 'str' and 'list'

# %%
Mprop="male_retreat_count"/["male_retreat_count"+ "female_retreat_count"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Mprop="male_retreat_count"/["male_retreat_count"+ "female_retreat_count"]
#
# TypeError: unsupported operand type(s) for /: 'str' and 'list'

# %%
def Mprop()
    'male_retreat_count'/['male_retreat_count'+ 'female_retreat_count']
# Out:
#   Cell In[9], line 1
#     def Mprop()
#                ^
# SyntaxError: expected ':'

# %%
def Mprop():
    'male_retreat_count'/['male_retreat_count'+ 'female_retreat_count']

# %%
VTT.Mprop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 VTT.Mprop()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Mprop'

# %%
VTT['Male_Proportion']=VTT['male_retreat_count']/[VTT['male_retreat_count'+'female_retreat_count']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'male_retreat_countfemale_retreat_count'
#
# ...

# %%
VTT['Male_Proportion']=VTT['male_retreat_count'] / (VTT['male_retreat_count'] + VTT['female_retreat_count'])

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTT['Female_proportion']=VTT['female_retreat_count'] / (VTT['female_retreat_count']+VTT['male_retreat_count'])

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
sns.stripplot(VTT)
# Out:
# <AxesSubplot: >

# %%
sns.stripplot([VTT['Male_Proportion'], VTT['Female_proportion']])
# Out:
# <AxesSubplot: >

# %%
Graph=sns.stripplot([VTT['Male_Proportion'], VTT['Female_proportion']], palette='dark:purple')
Graph.axhline(0.5, color='red')

# %%
sns.scatterplot([VTT['female_retreat_count'], VTT['male_retreat_count']])
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(data=VTT, x='male_retreat_count', y='female_retreat_count')
# Out:
# <AxesSubplot: xlabel='male_retreat_count', ylabel='female_retreat_count'>

# %%
sns.scatterplot(data=VTT, x='female_retreat_count', y='male_retreat_count')
# Out:
# <AxesSubplot: xlabel='female_retreat_count', ylabel='male_retreat_count'>

# %%
import matplotlib.pyplot as plt

# %%
VTT.boxplot(['female_retreat_count', 'male_retreat_count'])
# Out:
# <AxesSubplot: >

# %%
VTT.groupby('female_ID')

# %%
VTT['Day_Number']=[1, 1, 2, 1, 2, 1, 1, 2, 1, 2, 2, 3, 1, 1, 2, 2, 3, 2, 2, 2, 1, 1]

# %%
display(VTT)
# Out:
#     Unnamed: 0  Index          date  female_ID  male_ID  female_retreat_count  \
# 0            0      0    2022-11-09       4840     4829                     2
# 1            0      1    2022-11-10       4827     4834                     0
# 2            0      2    2022-12-21       4815     4784                     0
# 3            0      3    2022-11-08       4831     4824                     4
# 4            0      4    2022-12-07       4825     4830                     1
# 5            0      5    2022-11-08       4825     4830                     0
# 6            0      6    2022-11-09       4828     4835                     0
# 7            0      7    2022-12-21       4828     4835                     0
# 8            0      8    2022-11-09       4819     4833                     0
# 9            0      9    2022-12-20       4831     4824                     0
# 10           0     10    2022-12-20       4840     4829                     3
# ...

# %%
VTTD1=[VTT['Day_Number']==1]

# %%
display(VTTD1)
# Out:
# [0      True
#  1      True
#  2     False
#  3      True
#  4     False
#  5      True
#  6      True
#  7     False
#  8      True
#  9     False
#  10    False
#  11    False
#  12     True
#  13     True
#  14    False
#  15    False
#  16    False
#  17    False
#  18    False
#  19    False
#  20     True
#  21     True
#  Name: Day_Number, dtype: bool]

# %%
VTT.loc[VTT['Day_Number']==1].boxplot(['female_retreat_count', 'male_retreat_count'], color='red')
VTT.loc[VTT['Day_Number']==2].boxplot(['female_retreat_count', 'male_retreat_count'], color='yellow')
# Out:
# <AxesSubplot: >

# %%
VTT.loc[VTT['Day_Number']==1].boxplot(['female_retreat_count'])
VTT.loc[VTT['Day_Number']==2].boxplot(['female_retreat_count'])
VTT.loc[VTT['Day_Number']==1].boxplot(['male_retreat_count'])
VTT.loc[VTT['Day_Number']==2].boxplot(['male_retreat_count'])
# Out:
# <AxesSubplot: >

# %%
VTT.boxplot(['female_retreat_count', 'male_retreat_count'], by='Day_Number')
# Out:
# array([<AxesSubplot: title={'center': 'female_retreat_count'}, xlabel='Day_Number'>,
#        <AxesSubplot: title={'center': 'male_retreat_count'}, xlabel='Day_Number'>],
#       dtype=object)

# %%
if VTT['Day_Number'] <3:
    VTT.boxplot(['female_retreat_count', 'male_retreat_count'], by='Day_Number')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 if VTT['Day_Number'] <3:
#       2     VTT.boxplot(['female_retreat_count', 'male_retreat_count'], by='Day_Number')
#
# File ~\Documents\Anaconda\envs\Donaldson\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
